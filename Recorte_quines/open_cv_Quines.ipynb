# %%
# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Importar librerías necesarias
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Ruta de la imagen en Drive (ajusta según tu estructura de carpetas)
ruta_imagen = '/content/drive/My Drive/GEO_DS/Recorte_quines/Recorte_Quines.tif'

# Leer la imagen
imagen = cv2.imread(ruta_imagen)

if imagen is None:
    print(f"Error: No se pudo cargar la imagen en {ruta_imagen}")
    print("Verifica que el archivo exista y la ruta sea correcta")
else:
    print(f"Imagen cargada exitosamente. Dimensiones: {imagen.shape}")

    # Convertir a escala de grises
    gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

    # Aplicar desenfoque gaussiano para reducir ruido
    gris_blur = cv2.medianBlur(gris, 5)

    # Aplicar Hough Circle Transform
    # Parámetros:
    # - imagen en escala de grises
    # - método de detección (HOUGH_GRADIENT)
    # - dp: resolución del acumulador (1 = misma resolución que la imagen)
    # - minDist: distancia mínima entre centros de círculos detectados
    # - param1: umbral superior para Canny edge detector
    # - param2: umbral del acumulador para centros de círculos
    # - minRadius y maxRadius: rango de radios a detectar

    circulos = cv2.HoughCircles(
        gris_blur,
        cv2.HOUGH_GRADIENT,
        dp=1,
        minDist=100,
        param1=100,
        param2=30,
        minRadius=10,
        maxRadius=100
    )

    # Crear copia de la imagen original para dibujar
    imagen_resultado = imagen.copy()

    if circulos is not None:
        # Convertir a enteros
        circulos = np.uint16(np.around(circulos))

        print(f"Se detectaron {len(circulos[0])} círculos")

        # Dibujar los círculos detectados
        for i in circulos[0, :]:
            # Dibujar el círculo exterior
            cv2.circle(imagen_resultado, (i[0], i[1]), i[2], (0, 255, 0), 2)
            # Dibujar el centro del círculo
            cv2.circle(imagen_resultado, (i[0], i[1]), 2, (0, 0, 255), 3)

        print("\nInformación de los círculos detectados:")
        print("(Centro X, Centro Y, Radio)")
        for idx, i in enumerate(circulos[0, :]):
            print(f"Círculo {idx+1}: Centro=({i[0]}, {i[1]}), Radio={i[2]}")
    else:
        print("No se detectaron círculos. Intenta ajustar los parámetros.")

    # Visualizar resultados separadamente

    # Imagen original
    plt.figure(figsize=(8, 6))
    plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))
    plt.title('Imagen Original')
    plt.axis('off')
    plt.show()

    # Imagen en escala de grises
    plt.figure(figsize=(8, 6))
    plt.imshow(gris, cmap='gray')
    plt.title('Escala de Grises')
    plt.axis('off')
    plt.show()

    # Imagen con círculos detectados
    plt.figure(figsize=(8, 6))
    plt.imshow(cv2.cvtColor(imagen_resultado, cv2.COLOR_BGR2RGB))
    plt.title(f'Círculos Detectados ({len(circulos[0]) if circulos is not None else 0})')
    plt.axis('off')
    plt.show()

    # Guardar imagen resultante (opcional)
    #ruta_salida = '/content/drive/MyDrive/Recorte_R4_circulos.png'
    #cv2.imwrite(ruta_salida, imagen_resultado)
    #print(f"\nImagen con círculos guardada en: {ruta_salida}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Imagen cargada exitosamente. Dimensiones: (3774, 3953, 3)
# Se detectaron 232 círculos
#
# Información de los círculos detectados:
# (Centro X, Centro Y, Radio)
# Círculo 1: Centro=(1124, 1770), Radio=60
# Círculo 2: Centro=(2416, 436), Radio=68
# Círculo 3: Centro=(1020, 2264), Radio=62
# Círculo 4: Centro=(1786, 910), Radio=55
# Círculo 5: Centro=(2464, 1508), Radio=59
# Círculo 6: Centro=(2776, 902), Radio=60
# Círculo 7: Centro=(1010, 2410), Radio=53
# Círculo 8: Centro=(1098, 1894), Radio=61
# Círculo 9: Centro=(2756, 658), Radio=60
# Círculo 10: Centro=(2556, 432), Radio=68
# Círculo 11: Centro=(1226, 2546), Radio=63
# Círculo 12: Centro=(3162, 1716), Radio=95
# Círculo 13: Centro=(3246, 1614), Radio=99
# Círculo 14: Centro=(2056, 1292), Radio=62
# Círculo 15: Centro=(1228, 2362), Radio=62
# Círculo 16: Centro=(3010, 794), Radio=47
# Círculo 17: Centro=(1442, 1912), Radio=67
# Círculo 18: Centro=(1342, 2500), Radio=63
# Círculo 19: Centro=(1026, 2138), Radio=62
# Círculo 20: Centro=(3028, 1608), Radio=81
# Círculo 21: Centro=(2748, 536), Radio=61
# Círculo 22: Centro=(2756, 1386), Radio=52
# Círculo 23: Centro=(2644, 794), Radio=61
# Círculo 24: Centro=(1062, 2016), Radio=60
# Círculo 25: Centro=(1728, 3094), Radio=88
# Círculo 26: Centro=(1004, 2540), Radio=62
# Círculo 27: Centro=(2654, 920), Radio=58
# Círculo 28: Centro=(1454, 2418), Radio=48
# Círculo 29: Centro=(2924, 1646), Radio=99
# Círculo 30: Centro=(3026, 1748), Radio=99
# Círculo 31: Centro=(2426, 882), Radio=56
# Círculo 32: Centro=(2550, 1344), Radio=52
# Círculo 33: Centro=(3126, 1498), Radio=99
# Círculo 34: Centro=(2512, 686), Radio=61
# Círculo 35: Centro=(1108, 2348), Radio=60
# Círculo 36: Centro=(2930, 1138), Radio=52
# Círculo 37: Centro=(3738, 228), Radio=82
# Círculo 38: Centro=(1198, 2122), Radio=64
# Círculo 39: Centro=(496, 3476), Radio=43
# Círculo 40: Centro=(1592, 1588), Radio=59
# Círculo 41: Centro=(1148, 2236), Radio=62
# Círculo 42: Centro=(1690, 2998), Radio=90
# Círculo 43: Centro=(2700, 416), Radio=64
# Círculo 44: Centro=(3262, 1468), Radio=97
# Círculo 45: Centro=(2534, 934), Radio=60
# Círculo 46: Centro=(1184, 1996), Radio=62
# Círculo 47: Centro=(2890, 766), Radio=61
# Círculo 48: Centro=(2432, 754), Radio=47
# Círculo 49: Centro=(1824, 3066), Radio=70
# Círculo 50: Centro=(2902, 622), Radio=92
# Círculo 51: Centro=(2380, 1582), Radio=52
# Círculo 52: Centro=(1506, 3216), Radio=87
# Círculo 53: Centro=(1348, 2338), Radio=61
# Círculo 54: Centro=(3370, 1540), Radio=77
# Círculo 55: Centro=(1122, 2478), Radio=64
# Círculo 56: Centro=(2898, 886), Radio=61
# Círculo 57: Centro=(2480, 1622), Radio=60
# Círculo 58: Centro=(1648, 1482), Radio=50
# Círculo 59: Centro=(1864, 3234), Radio=93
# Círculo 60: Centro=(2526, 810), Radio=64
# Círculo 61: Centro=(2860, 1226), Radio=45
# Círculo 62: Centro=(3090, 436), Radio=43
# Círculo 63: Centro=(884, 3254), Radio=96
# Círculo 64: Centro=(2944, 1522), Radio=95
# Círculo 65: Centro=(1236, 1884), Radio=59
# Círculo 66: Centro=(2858, 1410), Radio=52
# Círculo 67: Centro=(1110, 2602), Radio=62
# Círculo 68: Centro=(2634, 668), Radio=60
# Círculo 69: Centro=(1500, 1802), Radio=57
# Círculo 70: Centro=(1588, 3036), Radio=99
# Círculo 71: Centro=(1422, 2706), Radio=78
# Círculo 72: Centro=(2490, 550), Radio=58
# Círculo 73: Centro=(1624, 2920), Radio=83
# Círculo 74: Centro=(2912, 488), Radio=99
# Círculo 75: Centro=(2770, 780), Radio=64
# Círculo 76: Centro=(1438, 2100), Radio=91
# Círculo 77: Centro=(908, 2478), Radio=49
# Círculo 78: Centro=(1568, 2320), Radio=49
# Círculo 79: Centro=(1490, 2602), Radio=99
# Círculo 80: Centro=(2622, 548), Radio=62
# Círculo 81: Centro=(2622, 1258), Radio=45
# Círculo 82: Centro=(1490, 3568), Radio=99
# Círculo 83: Centro=(3132, 1602), Radio=53
# Círculo 84: Centro=(3174, 1844), Radio=99
# Círculo 85: Centro=(3396, 1648), Radio=84
# Círculo 86: Centro=(3360, 1402), Radio=72
# Círculo 87: Centro=(1978, 3490), Radio=93
# Círculo 88: Centro=(1420, 2228), Radio=69
# Círculo 89: Centro=(1070, 3068), Radio=70
# Círculo 90: Centro=(1270, 2244), Radio=63
# Círculo 91: Centro=(3056, 1164), Radio=58
# Círculo 92: Centro=(1040, 2944), Radio=99
# Círculo 93: Centro=(1500, 2952), Radio=80
# Círculo 94: Centro=(940, 3372), Radio=67
# Círculo 95: Centro=(3004, 524), Radio=74
# Círculo 96: Centro=(1782, 2958), Radio=48
# Círculo 97: Centro=(1280, 2652), Radio=54
# Círculo 98: Centro=(2652, 1366), Radio=52
# Círculo 99: Centro=(1606, 3182), Radio=76
# Círculo 100: Centro=(3156, 964), Radio=99
# Círculo 101: Centro=(3878, 110), Radio=49
# Círculo 102: Centro=(1646, 2502), Radio=82
# Círculo 103: Centro=(3262, 1738), Radio=70
# Círculo 104: Centro=(3234, 432), Radio=42
# Círculo 105: Centro=(1478, 3058), Radio=91
# Círculo 106: Centro=(3796, 2600), Radio=91
# Círculo 107: Centro=(980, 1808), Radio=56
# Círculo 108: Centro=(3224, 1064), Radio=68
# Círculo 109: Centro=(2096, 10), Radio=57
# Círculo 110: Centro=(1556, 1228), Radio=49
# Círculo 111: Centro=(2204, 1508), Radio=41
# Círculo 112: Centro=(3120, 650), Radio=87
# Círculo 113: Centro=(2596, 3436), Radio=84
# Círculo 114: Centro=(1380, 2600), Radio=64
# Círculo 115: Centro=(1922, 3334), Radio=64
# Círculo 116: Centro=(1014, 3200), Radio=53
# Círculo 117: Centro=(3072, 1268), Radio=70
# Círculo 118: Centro=(3198, 1380), Radio=88
# Círculo 119: Centro=(824, 3476), Radio=88
# Círculo 120: Centro=(1400, 3326), Radio=61
# Círculo 121: Centro=(2986, 366), Radio=77
# Círculo 122: Centro=(2824, 1118), Radio=56
# Círculo 123: Centro=(3464, 1438), Radio=84
# Círculo 124: Centro=(3478, 1254), Radio=80
# Círculo 125: Centro=(2998, 690), Radio=52
# Círculo 126: Centro=(1340, 1894), Radio=78
# Círculo 127: Centro=(2358, 1478), Radio=60
# Círculo 128: Centro=(2346, 808), Radio=49
# Círculo 129: Centro=(1902, 3582), Radio=86
# Círculo 130: Centro=(1604, 2806), Radio=97
# Círculo 131: Centro=(3702, 2466), Radio=76
# Círculo 132: Centro=(3010, 1032), Radio=88
# Círculo 133: Centro=(1824, 254), Radio=78
# Círculo 134: Centro=(3048, 114), Radio=58
# Círculo 135: Centro=(1532, 2184), Radio=39
# Círculo 136: Centro=(2258, 2550), Radio=80
# Círculo 137: Centro=(3346, 1220), Radio=91
# Círculo 138: Centro=(2760, 1198), Radio=56
# Círculo 139: Centro=(2170, 3630), Radio=93
# Círculo 140: Centro=(1452, 3454), Radio=65
# Círculo 141: Centro=(452, 3382), Radio=43
# Círculo 142: Centro=(1310, 3414), Radio=66
# Círculo 143: Centro=(3316, 604), Radio=58
# Círculo 144: Centro=(1492, 1688), Radio=82
# Círculo 145: Centro=(3592, 194), Radio=60
# Círculo 146: Centro=(2100, 3486), Radio=46
# Círculo 147: Centro=(3082, 254), Radio=73
# Círculo 148: Centro=(3008, 896), Radio=48
# Círculo 149: Centro=(3534, 792), Radio=72
# Círculo 150: Centro=(2412, 3606), Radio=62
# Círculo 151: Centro=(2514, 1150), Radio=46
# Círculo 152: Centro=(1870, 3706), Radio=38
# Círculo 153: Centro=(3668, 3668), Radio=45
# Círculo 154: Centro=(2900, 1318), Radio=50
# Círculo 155: Centro=(2888, 3216), Radio=32
# Círculo 156: Centro=(660, 3040), Radio=75
# Círculo 157: Centro=(3498, 1558), Radio=70
# Círculo 158: Centro=(1810, 3528), Radio=50
# Círculo 159: Centro=(660, 3632), Radio=48
# Círculo 160: Centro=(2704, 3532), Radio=72
# Círculo 161: Centro=(2780, 2038), Radio=70
# Círculo 162: Centro=(1466, 3710), Radio=61
# Círculo 163: Centro=(790, 3318), Radio=60
# Círculo 164: Centro=(1554, 2420), Radio=49
# Círculo 165: Centro=(2382, 548), Radio=46
# Círculo 166: Centro=(1368, 2974), Radio=45
# Círculo 167: Centro=(2398, 3728), Radio=45
# Círculo 168: Centro=(1722, 2862), Radio=50
# Círculo 169: Centro=(1896, 2992), Radio=54
# Círculo 170: Centro=(3116, 830), Radio=58
# Círculo 171: Centro=(2368, 3474), Radio=56
# Círculo 172: Centro=(2960, 1238), Radio=55
# Círculo 173: Centro=(1662, 158), Radio=36
# Círculo 174: Centro=(1480, 2806), Radio=29
# Círculo 175: Centro=(1144, 2862), Radio=65
# Círculo 176: Centro=(3084, 2834), Radio=47
# Círculo 177: Centro=(2830, 328), Radio=93
# Círculo 178: Centro=(3320, 2928), Radio=40
# Círculo 179: Centro=(2030, 402), Radio=29
# Círculo 180: Centro=(2710, 3358), Radio=54
# Círculo 181: Centro=(1890, 514), Radio=46
# Círculo 182: Centro=(2954, 190), Radio=56
# Círculo 183: Centro=(3002, 2776), Radio=54
# Círculo 184: Centro=(1196, 3702), Radio=42
# Círculo 185: Centro=(934, 2980), Radio=58
# Círculo 186: Centro=(3174, 304), Radio=46
# Círculo 187: Centro=(2722, 1100), Radio=46
# Círculo 188: Centro=(1680, 988), Radio=42
# Círculo 189: Centro=(3700, 536), Radio=36
# Círculo 190: Centro=(1542, 1922), Radio=61
# Círculo 191: Centro=(1780, 1390), Radio=58
# Círculo 192: Centro=(996, 1692), Radio=44
# Círculo 193: Centro=(2282, 3528), Radio=34
# Círculo 194: Centro=(1924, 3154), Radio=28
# Círculo 195: Centro=(1328, 3232), Radio=64
# Círculo 196: Centro=(776, 3588), Radio=41
# Círculo 197: Centro=(3604, 2904), Radio=49
# Círculo 198: Centro=(2686, 2158), Radio=55
# Círculo 199: Centro=(1354, 792), Radio=27
# Círculo 200: Centro=(292, 1444), Radio=28
# Círculo 201: Centro=(546, 3088), Radio=47
# Círculo 202: Centro=(358, 2608), Radio=37
# Círculo 203: Centro=(450, 3146), Radio=56
# Círculo 204: Centro=(2832, 1548), Radio=46
# Círculo 205: Centro=(1750, 3192), Radio=34
# Círculo 206: Centro=(2792, 3612), Radio=30
# Círculo 207: Centro=(342, 3072), Radio=49
# Círculo 208: Centro=(1708, 2616), Radio=28
# Círculo 209: Centro=(2248, 2032), Radio=22
# Círculo 210: Centro=(3122, 1078), Radio=33
# Círculo 211: Centro=(2856, 1724), Radio=30
# Círculo 212: Centro=(3260, 952), Radio=46
# Círculo 213: Centro=(3122, 534), Radio=23
# Círculo 214: Centro=(2242, 3730), Radio=32
# Círculo 215: Centro=(3220, 2890), Radio=31
# Círculo 216: Centro=(3304, 1314), Radio=32
# Círculo 217: Centro=(1324, 2156), Radio=51
# Círculo 218: Centro=(1616, 3302), Radio=46
# Círculo 219: Centro=(3468, 3276), Radio=30
# Círculo 220: Centro=(2726, 2652), Radio=28
# Círculo 221: Centro=(2044, 3382), Radio=36
# Círculo 222: Centro=(784, 3200), Radio=34
# Círculo 223: Centro=(1956, 332), Radio=17
# Círculo 224: Centro=(1788, 1018), Radio=17
# Círculo 225: Centro=(238, 3542), Radio=16
# Círculo 226: Centro=(1674, 2730), Radio=15
# Círculo 227: Centro=(1714, 252), Radio=37
# Círculo 228: Centro=(3774, 3684), Radio=29
# Círculo 229: Centro=(1138, 2982), Radio=14
# Círculo 230: Centro=(3874, 2874), Radio=25
# Círculo 231: Centro=(2644, 3198), Radio=25
# Círculo 232: Centro=(668, 456), Radio=38
